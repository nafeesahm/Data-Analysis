# %% [markdown]
# # Pandas

# %% [markdown]
# #

# %%
import pandas as pd

# %% [markdown]
# # How to create a data

# %%
dict= { "name": ["nafees", "anis", "sheesh", "faiz"],
        "city": ["muzaffarpur", "darbhanga", "patna", "delhi"],
        "marks": [66, 97, 87]
      }

# %%
dict
# Out:
# {'name': ['nafees', 'anis', 'sheesh', 'faiz'],
#  'city': ['muzaffarpur', 'darbhanga', 'patna', 'delhi'],
#  'marks': [66, 97, 87]}

# %% [markdown]
# # make a Data Frame

# %%
df= pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # How to save data in csv format

# %%
df.to_csv("mydata.csv")

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.to_csv("newdata.csv", index=False)           # index= False ,  index remove from data after save

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #

# %% [markdown]
# # How to Load dataset

# %%
data= pd.read_csv("abalone.csv")               # data reading

# %%
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
data.head(4)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10

# %% [markdown]
# #  how to get random data

# %%
data.sample()           # give us random data
# Out:
#     Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 339   F   0.565      0.45   0.195        1.0035           0.406
#
#      Viscera weight  Shell weight  Rings
# 339          0.2505         0.285     15

# %%
data.sample(10)            # get 10 random data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 733    M   0.505     0.380   0.130        0.6560          0.2270
# 2538   M   0.660     0.535   0.200        1.7910          0.7330
# 2692   M   0.650     0.515   0.125        1.1805          0.5235
# 2251   M   0.600     0.485   0.175        1.2675          0.4995
# 68     F   0.475     0.390   0.120        0.5305          0.2135
# 1502   M   0.630     0.480   0.150        1.2710          0.6605
# 3872   F   0.515     0.400   0.115        0.5780          0.1910
# 1819   M   0.695     0.530   0.190        1.7260          0.7625
# 1253   I   0.420     0.305   0.090        0.3280          0.1680
# 3846   I   0.370     0.275   0.085        0.2045          0.0960
#
#       Viscera weight  Shell weight  Rings
# 733           0.1785        0.2200     13
# 2538          0.3180        0.5400     15
# 2692          0.2830        0.3275      9
# 2251          0.2815        0.3800     13
# 68            0.1155        0.1700     10
# 1502          0.2425        0.3100     11
# 3872          0.1445        0.1700      9
# 1819          0.4360        0.4550     11
# 1253          0.0615        0.0820      6
# 3846          0.0560        0.0800      6

# %% [markdown]
# # How to get all columns name

# %%
data.columns               # get every columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# # how to get information about data

# %%
data.info                  # get information about data
# Out:
# <bound method DataFrame.info of      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]>

# %% [markdown]
# # how to check null value  in data

# %%
data.isnull()                       # get  null value from data
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False         False  False
# 1              False         False  False
# 2              False         False  False
# 3              False         False  False
# 4              False         False  False
# ...              ...           ...    ...
# 4172           False         False  False
# 4173           False         False  False
# 4174           False         False  False
# 4175           False         False  False
# 4176           False         False  False
#
# [4177 rows x 9 columns]

# %%
data.isnull().sum()                 # get  null value from data
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# # Statics

# %%
data.describe()               # describe tha data in statical form
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000
